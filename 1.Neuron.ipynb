# %%
import torch
import torch.nn as nn

# %%
torch.manual_seed(42)
inputs=torch.tensor([1.0,2.0,2.0])

# %%
neuron=nn.Linear(in_features=3,out_features=1)

# %%
neuron.bias
# Out:
# Parameter containing:
# tensor([0.5304], requires_grad=True)

# %%
neuron.weight
# Out:
# Parameter containing:
# tensor([[ 0.4414,  0.4792, -0.1353]], requires_grad=True)

# %%
output=neuron(inputs)

# %%
output
# Out:
# tensor([1.6597], grad_fn=<ViewBackward0>)

# %%
#verify

neuron.weight @ inputs + neuron.bias
# Out:
# tensor([1.6597], grad_fn=<AddBackward0>)
